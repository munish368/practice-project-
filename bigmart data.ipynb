# %%
import pandas as pd

# %%
df = pd.read_csv("bigdatamart_Train.csv")

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Item_Weight'].mean()
# Out:
# 12.857645184136183

# %%
df['Item_Weight'].skew()
# Out:
# 0.0824262091221237

# %%
df['Item_Weight'].max()
# Out:
# 21.35

# %%
df['Item_Weight'].min()
# Out:
# 4.555

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(df["Item_Weight"])
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Density'>

# %%
meanvalue = df["Item_Weight"].mean()

# %%
meanvalue
# Out:
# 12.857645184136183

# %%
df["Item_Weight"].fillna(meanvalue,inplace = True)

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.drop(["Outlet_Size"],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Location_Type        Outlet_Type  \
# 0                       1999               Tier 1  Supermarket Type1
# 1                       2009               Tier 3  Supermarket Type2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Location_Type       8523 non-null   object
#  9   Outlet_Type                8523 non-null   object
#  10  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 732.6+ KB

# %%
df.shape
# Out:
# (8523, 11)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
       df[i]=le.fit_transform(df[i].values.reshape(-1,1))

# %%
df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 1         0.016047          4
# 1                8         5.92                 2         0.019278         14
# 2              662        17.50                 1         0.016760         10
# 3             1121        19.20                 2         0.000000          6
# 4             1297         8.93                 1         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0  249.8092                  9                       1999
# 1   48.2692                  3                       2009
# 2  141.6180                  9                       1999
# 3  182.0950                  0                       1998
# 4   53.8614                  1                       1987
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                     0            1          3735.1380
# ...

# %%
df.corr()
# Out:
#                            Item_Identifier  Item_Weight  Item_Fat_Content  \
# Item_Identifier                   1.000000     0.044518         -0.098114
# Item_Weight                       0.044518     1.000000         -0.017331
# Item_Fat_Content                 -0.098114    -0.017331          1.000000
# Item_Visibility                  -0.025482    -0.012049          0.034042
# Item_Type                        -0.017973     0.028015         -0.115958
# Item_MRP                          0.012853     0.024756         -0.000876
# Outlet_Identifier                -0.008602    -0.007975         -0.002357
# Outlet_Establishment_Year        -0.012772    -0.008301         -0.000189
# Outlet_Location_Type              0.003656     0.004088         -0.004102
# Outlet_Type                      -0.001178    -0.000566         -0.004214
# Item_Outlet_Sales                 0.002869     0.011550          0.009800
#
#                            Item_Visibility  Item_Type  Item_MRP  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
df.drop(["Outlet_Location_Type"],axis = 1,inplace = True)

# %%
df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 1         0.016047          4
# 1                8         5.92                 2         0.019278         14
# 2              662        17.50                 1         0.016760         10
# 3             1121        19.20                 2         0.000000          6
# 4             1297         8.93                 1         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Type  \
# 0  249.8092                  9                       1999            1
# 1   48.2692                  3                       2009            2
# 2  141.6180                  9                       1999            1
# 3  182.0950                  0                       1998            0
# 4   53.8614                  1                       1987            1
#
#    Item_Outlet_Sales
# 0          3735.1380
# 1           443.4228
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
sns.distplot(df["Item_Identifier"])
# Out:
# <AxesSubplot:xlabel='Item_Identifier', ylabel='Density'>

# %%
sns.violinplot(df["Item_Identifier"])
# Out:
# <AxesSubplot:xlabel='Item_Identifier'>

# %%
sns.distplot(df["Item_Weight"])
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Density'>

# %%
sns.violinplot(df["Item_Weight"])
# Out:
# <AxesSubplot:xlabel='Item_Weight'>

# %%
sns.distplot(df["Item_Fat_Content"])
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Density'>

# %%
sns.violinplot(df["Item_Fat_Content"])
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content'>

# %%
sns.distplot(df["Item_Visibility"])
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Density'>

# %%
sns.violinplot(df["Item_Visibility"])
# Out:
# <AxesSubplot:xlabel='Item_Visibility'>

# %%
sns.distplot(df["Item_Type"])
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Density'>

# %%
sns.violinplot(df["Item_Type"])
# Out:
# <AxesSubplot:xlabel='Item_Type'>

# %%
sns.distplot(df["Item_MRP"])
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Density'>

# %%
sns.violinplot(df["Item_MRP"])
# Out:
# <AxesSubplot:xlabel='Item_MRP'>

# %%
sns.distplot(df["Outlet_Identifier"])
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='Density'>

# %%
sns.violinplot(df["Outlet_Identifier"])
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier'>

# %%
sns.distplot(df["Outlet_Establishment_Year"])
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Density'>

# %%
sns.violinplot(df["Outlet_Establishment_Year"])
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year'>

# %%
sns.distplot(df["Outlet_Type"])
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='Density'>

# %%
sns.violinplot(df["Outlet_Type"])
# Out:
# <AxesSubplot:xlabel='Outlet_Type'>

# %%
sns.catplot(x="Item_Fat_Content",y="Item_Outlet_Sales",kind="bar",data=df)

# %%
sns.lineplot(x="Item_Weight",y="Item_Fat_Content",data=df)
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Item_Fat_Content'>

# %%
sns.relplot(x="Item_Weight",y="Item_Fat_Content",data=df)

# %%
sns.regplot(x="Item_Weight",y="Item_Fat_Content",data=df)
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Item_Fat_Content'>

# %%
df["Item_Fat_Content"].unique()
# Out:
# array([1, 2, 3, 0, 4])

# %%
sns.catplot(x="Item_Fat_Content",y="Item_Weight",kind="bar",data=df)

# %%
df['Item_Identifier'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Item_Weight'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Item_Fat_Content'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Item_Visibility'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Item_Type'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Item_MRP'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Outlet_Identifier'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Outlet_Establishment_Year'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Outlet_Type'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box',subplots=True,layout=(2,5),figsize=(10,6))
# Out:
# Item_Identifier                 AxesSubplot(0.125,0.536818;0.133621x0.343182)
# Item_Weight                  AxesSubplot(0.285345,0.536818;0.133621x0.343182)
# Item_Fat_Content              AxesSubplot(0.44569,0.536818;0.133621x0.343182)
# Item_Visibility              AxesSubplot(0.606034,0.536818;0.133621x0.343182)
# Item_Type                    AxesSubplot(0.766379,0.536818;0.133621x0.343182)
# Item_MRP                           AxesSubplot(0.125,0.125;0.133621x0.343182)
# Outlet_Identifier               AxesSubplot(0.285345,0.125;0.133621x0.343182)
# Outlet_Establishment_Year        AxesSubplot(0.44569,0.125;0.133621x0.343182)
# Outlet_Type                     AxesSubplot(0.606034,0.125;0.133621x0.343182)
# Item_Outlet_Sales               AxesSubplot(0.766379,0.125;0.133621x0.343182)
# dtype: object

# %%
sns.distplot(df["Item_Identifier"])
# Out:
# <AxesSubplot:xlabel='Item_Identifier', ylabel='Density'>

# %%
sns.distplot(df["Item_Weight"])
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Density'>

# %%
sns.distplot(df["Item_Fat_Content"])
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Density'>

# %%
sns.distplot(df["Item_Visibility"])
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Density'>

# %%
sns.distplot(df["Item_Type"])
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Density'>

# %%
sns.distplot(df["Item_MRP"])
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Density'>

# %%
sns.distplot(df["Outlet_Identifier"])
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='Density'>

# %%
sns.distplot(df["Outlet_Establishment_Year"])
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Density'>

# %%
sns.distplot(df["Outlet_Type"])
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='Density'>

# %%
df.skew()
# Out:
# Item_Identifier             -0.008877
# Item_Weight                  0.090561
# Item_Fat_Content             0.994824
# Item_Visibility              1.167091
# Item_Type                    0.101655
# Item_MRP                     0.127202
# Outlet_Identifier           -0.059861
# Outlet_Establishment_Year   -0.396641
# Outlet_Type                  0.927438
# Item_Outlet_Sales            1.177531
# dtype: float64

# %%
from scipy.stats import skew

# %%
for i in df:
    print(i)
    print(skew(df[i]))
     
    plt.figure()
    sns.distplot(df[i])
    plt.show()
# Out:
# Item_Identifier
# -0.008875615439270857
# Item_Weight
# 0.09054551283289146
# Item_Fat_Content
# 0.9946491351111667
# Item_Visibility
# 1.16688513828559
# Item_Type
# 0.10163673290111704
# Item_MRP
# 0.1271798803336854
# Outlet_Identifier
# -0.059850846024945475
# Outlet_Establishment_Year
# -0.39657097595805835
# Outlet_Type
# 0.9272749842008103
# Item_Outlet_Sales
# 1.177323353967637

# %%
df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 1         0.016047          4
# 1                8         5.92                 2         0.019278         14
# 2              662        17.50                 1         0.016760         10
# 3             1121        19.20                 2         0.000000          6
# 4             1297         8.93                 1         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Type  \
# 0  249.8092                  9                       1999            1
# 1   48.2692                  3                       2009            2
# 2  141.6180                  9                       1999            1
# 3  182.0950                  0                       1998            0
# 4   53.8614                  1                       1987            1
#
#    Item_Outlet_Sales
# 0          3735.1380
# 1           443.4228
# ...

# %%
x= df.iloc[:,0:-1]

# %%
x.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 1         0.016047          4
# 1                8         5.92                 2         0.019278         14
# 2              662        17.50                 1         0.016760         10
# 3             1121        19.20                 2         0.000000          6
# 4             1297         8.93                 1         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Type
# 0  249.8092                  9                       1999            1
# 1   48.2692                  3                       2009            2
# 2  141.6180                  9                       1999            1
# 3  182.0950                  0                       1998            0
# 4   53.8614                  1                       1987            1

# %%
y = df.iloc[:,-1]

# %%
y.head()
# Out:
# 0    3735.1380
# 1     443.4228
# 2    2097.2700
# 3     732.3800
# 4     994.7052
# Name: Item_Outlet_Sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=35)

# %%
x_train.shape
# Out:
# (6818, 9)

# %%
x_test.shape
# Out:
# (1705, 9)

# %%
y_train.shape
# Out:
# (6818,)

# %%
y_test.shape
# Out:
# (1705,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.metrics import accuracy_score

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.5039069520951707

# %%
predlr = lr.predict(x_test)

# %%
print(r2_score(y_test,predlr))
# Out:
# 0.49316106458324904

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
predrf = rf.predict(x_test)
print(r2_score(y_test,predrf))
# Out:
# 0.5444379666530406

# %%
from sklearn.svm import SVR

# %%
svr = SVR()

# %%
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
predsvr = svr.predict(x_test)
print(r2_score(y_test,predsvr))
# Out:
# -0.041090404143353965

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dr = DecisionTreeRegressor()

# %%
dr.fit(x_train,y_train)
dr.score(x_train,y_train)
# Out:
# 1.0

# %%
preddr = dr.predict(x_test)
print(r2_score(y_test,preddr))
# Out:
# 0.15034529431581722
